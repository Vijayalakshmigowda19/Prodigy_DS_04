# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
twitter = pd.read_csv('twitter_training.csv', on_bad_lines='skip', engine='python')
# on_bad_lines='skip' skips rows with parsing errors
# engine='python' uses the Python parsing engine which is more flexible with errors

# %%
twitter
# Out:
#         2401  Borderlands  Positive  \
# 0       2401  Borderlands  Positive
# 1       2401  Borderlands  Positive
# 2       2401  Borderlands  Positive
# 3       2401  Borderlands  Positive
# 4       2401  Borderlands  Positive
# ...      ...          ...       ...
# 103039  9200       Nvidia  Positive
# 103040  9200       Nvidia  Positive
# 103041  9200       Nvidia  Positive
# 103042  9200       Nvidia  Positive
# 103043  9200       Nvidia  Positive
#
#        im getting on borderlands and i will murder you all ,
# 0       I am coming to the borders and I will kill you...
# 1       im getting on borderlands and i will kill you ...
# 2       im coming on borderlands and i will murder you...
# 3       im getting on borderlands 2 and i will murder ...
# 4       im getting into borderlands and i can murder y...
# ...                                                   ...
# 103039  Just realized that the Windows partition of my...
# ...

# %%
twitter.shape
# Out:
# (103044, 4)

# %%
twitter.columns
# Out:
# Index(['2401', 'Borderlands', 'Positive',
#        'im getting on borderlands and i will murder you all ,'],
#       dtype='object')

# %%
twitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103044 entries, 0 to 103043
# Data columns (total 4 columns):
#  #   Column                                                 Non-Null Count   Dtype
# ---  ------                                                 --------------   -----
#  0   2401                                                   103044 non-null  object
#  1   Borderlands                                            103042 non-null  object
#  2   Positive                                               103042 non-null  object
#  3   im getting on borderlands and i will murder you all ,  102115 non-null  object
# dtypes: object(4)
# memory usage: 3.1+ MB

# %%
twitter.isnull().sum()
# Out:
# 2401                                                       0
# Borderlands                                                2
# Positive                                                   2
# im getting on borderlands and i will murder you all ,    929
# dtype: int64

# %%
twitter.Borderlands.unique()
# Out:
# array(['Borderlands', 'CallOfDutyBlackopsColdWar', 'Amazon', 'Overwatch',
#        'Verizon', 'HomeDepot', 'FIFA', 'RedDeadRedemption(RDR)',
#        'CallOfDuty', 'Xbox(Xseries)', 'NBA2K', 'Dota2', None,
#        'TomClancysRainbowSix', 'Facebook', 'GrandTheftAuto(GTA)',
#        'PlayStation5(PS5)', 'WorldOfCraft', 'CS-GO', 'Google',
#        'MaddenNFL', 'johnson&johnson', 'Cyberpunk2077', 'AssassinsCreed',
#        'ApexLegends', 'LeagueOfLegends', 'TomClancysGhostRecon', 'Nvidia',
#        'Fortnite', 'Microsoft', 'Hearthstone', 'Battlefield',
#        'PlayerUnknownsBattlegrounds(PUBG)'], dtype=object)

# %%
twitter.Positive.unique()
# Out:
# array(['Positive', 'Neutral', 'Negative', 'Irrelevant', None],
#       dtype=object)

# %%
twitter.isnull().sum()
# Out:
# 2401                                                       0
# Borderlands                                                2
# Positive                                                   2
# im getting on borderlands and i will murder you all ,    929
# dtype: int64

# %%
twitter.to_csv('twitter1.csv', index=False)
# importing file from a local folder
from google.colab import files
files.download('twitter1.csv')
